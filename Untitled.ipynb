# %%
import numpy as np
import pandas as pd
from fancyimpute import KNN
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency
import seaborn as sns
from random import randrange, uniform
# Out:
# Using TensorFlow backend.

# %%
data = pd.read_excel('RealEstate.xlsx')
data
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1          2012.916667          32.0
# 1      2          2012.916667          19.5
# 2      3          2013.583333          13.3
# 3      4          2013.500000          13.3
# 4      5          2012.833333           5.0
# 5      6          2012.666667           7.1
# 6      7          2012.666667          34.5
# 7      8          2013.416667          20.3
# 8      9          2013.500000          31.7
# 9     10          2013.416667          17.9
# 10    11          2013.083333          34.8
# 11    12          2013.333333           6.3
# 12    13          2012.916667          13.0
# 13    14          2012.666667          20.4
# 14    15          2013.500000          13.2
# 15    16          2013.583333          35.7
# 16    17          2013.250000           0.0
# 17    18          2012.750000          17.7
# 18    19          2013.416667          16.9
# 19    20          2012.666667           1.5
# ...

# %%
test = data.iloc[np.random.choice(np.arange(len(data)),30,False)].reset_index()
test= test.drop(['index'],axis=1)
train = data[~data['No'].isin(test['No'])]

# %%
train
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1          2012.916667          32.0
# 1      2          2012.916667          19.5
# 2      3          2013.583333          13.3
# 3      4          2013.500000          13.3
# 4      5          2012.833333           5.0
# 5      6          2012.666667           7.1
# 6      7          2012.666667          34.5
# 7      8          2013.416667          20.3
# 8      9          2013.500000          31.7
# 9     10          2013.416667          17.9
# 10    11          2013.083333          34.8
# 11    12          2013.333333           6.3
# 12    13          2012.916667          13.0
# 13    14          2012.666667          20.4
# 14    15          2013.500000          13.2
# 15    16          2013.583333          35.7
# 16    17          2013.250000           0.0
# 17    18          2012.750000          17.7
# 18    19          2013.416667          16.9
# 20    21          2013.416667           4.5
# ...

# %%
final_sol = test['Y house price of unit area']
test = test.drop(['Y house price of unit area'],axis=1)
test
# Out:
#      No  X1 transaction date  X2 house age  \
# 0   378          2013.333333           3.9
# 1   161          2012.916667           3.5
# 2   397          2012.666667          37.1
# 3   251          2013.166667          39.2
# 4    25          2013.000000          39.6
# 5   234          2013.333333          39.7
# 6   317          2013.250000          13.3
# 7    22          2013.416667          10.5
# 8   413          2013.000000           8.1
# 9    48          2013.583333          35.9
# 10  343          2012.666667           5.7
# 11  225          2013.333333          34.5
# 12  204          2012.666667          15.6
# 13  120          2013.500000          16.6
# 14  253          2012.833333           5.9
# 15  307          2013.500000          14.4
# 16   20          2012.666667           1.5
# 17  134          2012.833333          18.0
# 18   26          2013.083333          29.3
# 19  359          2013.166667           1.1
# 20  341          2013.333333          33.6
# ...
